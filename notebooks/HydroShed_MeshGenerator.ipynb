# %%
# =============================================================================
# Package Set Up
# =============================================================================
import sys
# !{sys.executable} -m pip install numpy scikit-image pymartini rasterio pyvista scipy
# Out:
# Requirement already satisfied: numpy in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (2.3.4)
# Requirement already satisfied: scikit-image in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (0.25.2)
# Requirement already satisfied: pymartini in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (0.5.1)
# Requirement already satisfied: rasterio in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (1.4.3)
# Requirement already satisfied: pyvista in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (0.46.3)
# Requirement already satisfied: scipy in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (1.16.2)
# Requirement already satisfied: networkx>=3.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: affine in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from rasterio) (3.2.5)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pyvista) (3.10.7)
# Requirement already satisfied: pooch in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pyvista) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pyvista) (0.10.2)
# Requirement already satisfied: typing-extensions>=4.10 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pyvista) (4.12.2)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pyvista) (9.5.2)
# Requirement already satisfied: colorama in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.1->pyvista) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.1->pyvista) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.1->pyvista) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pooch->pyvista) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from pooch->pyvista) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yamff\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (2.3.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\yamff\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# =============================================================================
# Notes ( Feel free to add more)
# =============================================================================
# modify dem_path accordingly to the tif file name
# output_vtp is what the name of the mesh file is and also where the file is created
# z_scale = 0.1 is used to reduce artifacts, messed around and found this to be a sweet spot
# max_size and level both affect detail

# %%
import numpy as np
from skimage.transform import resize
import pymartini
import rasterio
from pathlib import Path
import pyvista as pv
from scipy.ndimage import map_coordinates

data_dir = Path("../data")
dem_path = data_dir / "hyd_na_dem_30s.tif"
output_vtp = data_dir / "hyd_na_dem_30s_mesh_3d_corrected3.vtp"

# Load DEM and metadata
with rasterio.open(dem_path) as src:
    dem = src.read(1)
    transform = src.transform
    crs = src.crs
    nodata_val = src.nodata

# Handle NoData values: mask and fill with NaN
dem_masked = dem.astype(np.float32)
if nodata_val is not None:
    dem_masked[dem_masked == nodata_val] = np.nan

# Optionally clip extreme elevation values but ignore NaNs
valid_vals = dem_masked[~np.isnan(dem_masked)]
lower_clip = np.percentile(valid_vals, 1)
upper_clip = np.percentile(valid_vals, 99)
dem_clipped = np.clip(dem_masked, lower_clip, upper_clip)

# Resize DEM safely
max_size = 1025
dem_size = dem_clipped.shape[0]
target_size = min(max_size, 2 ** int(np.floor(np.log2(dem_size - 1))) + 1)
dem_resized = resize(dem_clipped, (target_size, target_size), preserve_range=True, anti_aliasing=True)
dem_resized = np.ascontiguousarray(dem_resized.astype(np.float32))

# Build Martini mesh
grid_size = dem_resized.shape[0]
martini = pymartini.Martini(grid_size)
tile = martini.create_tile(dem_resized)

# Extract mesh at desired level
level = 0
vertices, triangles = tile.get_mesh(level)
vertices = np.array(vertices, dtype=np.float32)
triangles = np.array(triangles, dtype=np.int32).reshape(-1, 3)

max_index = triangles.max()
vertices_xy = vertices[: (max_index + 1) * 2].reshape(-1, 2)
rows = vertices_xy[:, 0]
cols = vertices_xy[:, 1]

# Map grid indices to real-world coordinates (x, y)
rows_int = np.clip(np.round(rows).astype(int), 0, dem_resized.shape[0] - 1)
cols_int = np.clip(np.round(cols).astype(int), 0, dem_resized.shape[1] - 1)
xs, ys = rasterio.transform.xy(transform, rows_int, cols_int)
xs = np.array(xs, dtype=np.float32)
ys = np.array(ys, dtype=np.float32)

# Bilinear interpolate elevation for fractional vertices (rows, cols)
coords = np.vstack([rows, cols])
zs = map_coordinates(dem_resized, coords, order=1, mode='nearest')

# Fix NaN values by replacing with nearby valid elevations
nan_mask = np.isnan(zs)
if np.any(nan_mask):
    # Replace NaNs by nearest valid value (simple approach)
    zs[nan_mask] = np.nanmean(zs[~nan_mask])

# Normalize elevation ignoring NaNs
zs_min = np.nanmin(zs)
zs_max = np.nanmax(zs)
zs = (zs - zs_min) / (zs_max - zs_min)

# Vertical exaggeration
z_scale = 0.1
zs *= z_scale

# Stack into final vertices (X, Y, Z)
vertices_3d = np.column_stack([xs, ys, zs])

# Optional: center horizontally for better visualization
vertices_3d[:, 0] -= vertices_3d[:, 0].mean()
vertices_3d[:, 1] -= vertices_3d[:, 1].mean()

# Build faces for PyVista
faces = np.hstack([np.full((triangles.shape[0], 1), 3, dtype=np.int32), triangles]).flatten()

# Create mesh
mesh = pv.PolyData(vertices_3d, faces)

# Save mesh
mesh.save(output_vtp)

print(f"Vertices: {vertices_3d.shape}, Triangles: {triangles.shape}")
print(f"Mesh saved as VTP: {output_vtp}")
print("Mesh bounds:", mesh.bounds)
# Out:
# Vertices: (353940, 3), Triangles: (707803, 3)
# Mesh saved as VTP: ..\data\hyd_na_dem_30s_mesh_3d_corrected3.vtp
# Mesh bounds: BoundsTuple(x_min = -3.0358428955078125,
#             x_max =  5.49749755859375,
#             y_min = -4.286586761474609,
#             y_max =  4.246746063232422,
#             z_min =  0.0,
#             z_max =  0.10000000149011612)
